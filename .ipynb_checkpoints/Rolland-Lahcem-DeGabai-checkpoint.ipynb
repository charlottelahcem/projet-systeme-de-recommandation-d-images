# %% [markdown]
# ## Task 1: Data Collection
#
# ### Goal
# Collect at least **100 open-licensed images** with their metadata.
#
# ### What You Need to Do
#
# 1. **Create a folder structure**:
#
#    ```
#    project/
#    ├── images/           # Downloaded images
#    ├── data/             # JSON metadata files
#    └── project.ipynb     # Your notebook
#    ```
#
# 2. **Find image sources** (choose one or more):
#    - [Wikimedia Commons](https://commons.wikimedia.org/) - Use SPARQL queries (like in Practical 1)
#    - [Unsplash API](https://unsplash.com/developers) - Free API for high-quality images
#    - [Pexels API](https://www.pexels.com/api/) - Free stock photos
#    - [Flickr API](https://www.flickr.com/services/api/) - Creative Commons images
#
# 3. **Download images programmatically** using the techniques from Practical 1, Exercise 6
#
# 4. **Extract and save metadata** for each image:
#    - Image filename
#    - Image dimensions (width, height)
#    - File format (.jpg, .png, etc.)
#    - File size (in KB)
#    - Source URL
#    - License information
#    - EXIF data (if available): camera model, date taken, etc.
#
# ### Expected Output
# - `images/` folder with 100+ images
# - `data/images_metadata.json` containing metadata for all images
#
# ### Hints
# - Use `PIL` to get image dimensions
# - Use `os.path.getsize()` to get file size
# - Use EXIF extraction (see Practical 2, Exercise 2)
# - Store metadata as a list of dictionaries in JSON format
#
# ---

# %%
import sys
import os
import json
import time
import shutil
import requests
import pandas as pd
from urllib.parse import unquote
from PIL import Image
from PIL.ExifTags import TAGS
from SPARQLWrapper import SPARQLWrapper, JSON as SPARQL_JSON

import numpy
import math
import webcolors
import matplotlib.pyplot as plot
from sklearn.cluster import KMeans

os.makedirs('images', exist_ok=True)
os.makedirs('data',   exist_ok=True)

# %% [markdown]
# ENDPOINT_URL = 'https://query.wikidata.org/sparql'
#
# QUERIES = {
#     'mountain': '''
#         SELECT DISTINCT ?mountain ?mountainLabel ?mountainRange ?mountainRangeLabel ?image WHERE {
#           ?mountain wdt:P31 wd:Q8502 ;
#                     wdt:P4552 ?mountainRange ;
#                     wdt:P18 ?image .
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#         }
#         LIMIT 25
#     ''',
#     'cat': '''
#         SELECT DISTINCT ?itemLabel ?image WHERE {
#           ?item wdt:P31 wd:Q146 ;
#                 wdt:P18 ?image .
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#         }
#         LIMIT 25
#     ''',
#     'flower': '''
#         SELECT DISTINCT ?itemLabel ?image WHERE {
#           ?item wdt:P31 wd:Q506 ;
#                 wdt:P18 ?image .
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#         }
#         LIMIT 25
#     ''',
#     'city': '''
#         SELECT DISTINCT ?itemLabel ?image WHERE {
#           ?item wdt:P31 wd:Q5119 ;
#                 wdt:P18 ?image .
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#         }
#         LIMIT 25
#     ''',
#     'bird': '''
#         SELECT DISTINCT ?itemLabel ?image WHERE {
#           ?item wdt:P31 wd:Q16521 ;
#                 wdt:P171* wd:Q5113 ;
#                 wdt:P18 ?image .
#           SERVICE wikibase:label { bd:serviceParam wikibase:language "en". }
#         }
#         LIMIT 25
#     '''
# }
#
#
# def get_results(endpoint_url, query):
#     user_agent = 'WDQS-example Python/%s.%s' % (sys.version_info[0], sys.version_info[1])
#     sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
#     sparql.setQuery(query)
#     sparql.setReturnFormat(SPARQL_JSON)
#     return sparql.query().convert()
#
#
# all_images = []
#
# for category, query in QUERIES.items():
#     print(f'Requete SPARQL : {category}...')
#     try:
#         results = get_results(ENDPOINT_URL, query)
#         bindings = results['results']['bindings']
#         for result in bindings:
#             if category == 'mountain':
#                 label = result.get('mountainLabel', {}).get('value', '?')
#                 extra = result.get('mountainRangeLabel', {}).get('value', '')
#             else:
#                 label = result.get('itemLabel', {}).get('value', '?')
#                 extra = ''
#             all_images.append({
#                 'label':     label,
#                 'extra':     extra,
#                 'category':  category,
#                 'image_url': result['image']['value'],
#             })
#         print(f'  OK : {len(bindings)} images trouvees')
#         time.sleep(2)
#     except Exception as e:
#         print(f'  Erreur : {e}')
#
# print(f'\nTotal images collectees : {len(all_images)}')

# %% [markdown]
# def download_image(url, category, folder='images', max_retries=4):
#     dest_folder = os.path.join(folder, category)
#     os.makedirs(dest_folder, exist_ok=True)
#     headers = {'User-Agent': 'Mozilla/5.0 (WikidataImageProject)'}
#
#     for attempt in range(max_retries):
#         try:
#             request = requests.get(url, allow_redirects=True,
#                                    headers=headers, stream=True, timeout=20)
#             if request.status_code == 200:
#                 filename = unquote(os.path.basename(url.split('?')[0])).replace(' ', '_')
#                 filepath = os.path.join(dest_folder, filename)
#                 with open(filepath, 'wb') as image:
#                     request.raw.decode_content = True
#                     shutil.copyfileobj(request.raw, image)
#                 print('Saved to:', os.path.abspath(filepath))
#                 return filepath
#             elif request.status_code == 429:
#                 retry_after = int(request.headers.get('Retry-After', 2 ** (attempt + 2)))
#                 print(f'  429 Rate limit - attente {retry_after}s (tentative {attempt+1}/{max_retries})')
#                 time.sleep(retry_after)
#             else:
#                 print(f'Failed: {request.status_code} {url}')
#                 return None
#         except Exception as e:
#             wait = 2 ** (attempt + 1)
#             print(f'  Erreur ({e}) - attente {wait}s')
#             time.sleep(wait)
#
#     print(f'  Echec definitif apres {max_retries} tentatives : {url}')
#     return None
#
#
# def extract_exif(pil_image):
#     exif_data = {}
#     try:
#         raw_exif = pil_image._getexif()
#         if raw_exif:
#             for tag_id, value in raw_exif.items():
#                 tag = TAGS.get(tag_id, tag_id)
#                 if tag in ('Make', 'Model', 'DateTime', 'Software',
#                            'Orientation', 'XResolution', 'YResolution'):
#                     exif_data[tag] = str(value)
#     except Exception:
#         pass
#     return exif_data
#
#
# def extract_metadata(item):
#     filepath = item['local_path']
#     metadata = {
#         'filename':     os.path.basename(filepath),
#         'local_path':   filepath,
#         'source_url':   item['image_url'],   # URL conservee ici
#         'label':        item['label'],
#         'extra':        item.get('extra', ''),
#         'category':     item['category'],
#         'license':      'Wikimedia Commons (voir page source)',
#         'width':        None,
#         'height':       None,
#         'format':       None,
#         'file_size_kb': None,
#         'exif':         {}
#     }
#     try:
#         metadata['file_size_kb'] = round(os.path.getsize(filepath) / 1024, 2)
#         with Image.open(filepath) as img:
#             metadata['width']  = img.size[0]
#             metadata['height'] = img.size[1]
#             metadata['format'] = img.format
#             metadata['exif']   = extract_exif(img)
#     except Exception as e:
#         print(f'Impossible de lire {filepath} : {e}')
#     return metadata
#
#
# # Telechargement + extraction en meme temps
# downloaded = []
# all_metadata = []
#
# for item in all_images:
#     filepath = download_image(item['image_url'], item['category'])
#     if filepath:
#         item['local_path'] = filepath
#         downloaded.append(item)
#         all_metadata.append(extract_metadata(item))  # metadata extraite pendant que l'URL est dispo
#     time.sleep(1)
#
# print(f'{len(downloaded)} images telechargees.')
# print(f'{len(all_metadata)} metadonnees extraites.')
#
# # Sauvegarde JSON immediate
# OUTPUT_JSON = os.path.join('data', 'images_metadata.json')
# with open(OUTPUT_JSON, 'w', encoding='utf-8') as f:
#     json.dump(all_metadata, f, ensure_ascii=False, indent=2)
# print(f'Metadonnees sauvegardees dans : {OUTPUT_JSON}')

# %%
with open('data/images_metadata.json', 'r', encoding='utf-8') as f:
    all_metadata = json.load(f)

print(f'{len(all_metadata)} entrees chargees depuis le JSON.')
# Out:
# 119 entrees chargees depuis le JSON.

# %%
df = pd.DataFrame(all_metadata)

# Aplatir la colonne 'exif' en colonnes separees
df = pd.concat(
    [df.drop(columns='exif'),
     pd.json_normalize(df['exif']).add_prefix('exif_')],
    axis=1
)

df.to_csv('data/images_metadata.csv', index=False)

print(f'DataFrame : {df.shape[0]} lignes x {df.shape[1]} colonnes')
df.head()
# Out:
# DataFrame : 119 lignes x 18 colonnes
#                  filename                               local_path  \
# 0  Moosalp_Bonigersee.jpg  images/montagnes/Moosalp_Bonigersee.jpg
# 1            Hohtälli.JPG            images/montagnes/Hohtälli.JPG
# 2        MontRogneux.jpeg        images/montagnes/MontRogneux.jpeg
# 3       Roc_d'Orzival.jpg       images/montagnes/Roc_d'Orzival.jpg
# 4       Jagerhorn0001.jpg       images/montagnes/Jagerhorn0001.jpg
#
#                                           source_url          label  \
# 0  http://commons.wikimedia.org/wiki/Special:File...  Augstbordhorn
# 1  http://commons.wikimedia.org/wiki/Special:File...       Hohtälli
# 2  http://commons.wikimedia.org/wiki/Special:File...   Mont Rogneux
# 3  http://commons.wikimedia.org/wiki/Special:File...  Roc d'Orzival
# 4  http://commons.wikimedia.org/wiki/Special:File...      Jägerhorn
#
#           extra   category                               license   width  \
# 0  Pennine Alps  montagnes  Wikimedia Commons (voir page source)  1280.0
# 1  Pennine Alps  montagnes  Wikimedia Commons (voir page source)  1486.0
# 2  Pennine Alps  montagnes  Wikimedia Commons (voir page source)  4012.0
# 3  Pennine Alps  montagnes  Wikimedia Commons (voir page source)  6240.0
# 4  Pennine Alps  montagnes  Wikimedia Commons (voir page source)   600.0
#
#    height format  file_size_kb                exif_Make        exif_Model  \
# 0   887.0   JPEG       1563.03                Panasonic          DMC-TZ10
# 1  1031.0   JPEG        372.91  OLYMPUS OPTICAL CO.,LTD  X-2,C-50Z
# 2  1276.0   JPEG       3525.20                      NaN               NaN
# 3  4160.0   JPEG      15997.13                 FUJIFILM             X-T30
# 4   443.0   JPEG         80.95                      NaN               NaN
#
#                           exif_Software exif_Orientation        exif_DateTime  \
# 0  Adobe Photoshop Elements 3.0 Windows                1  2013:11:07 15:54:02
# 1       28-1011                                        1  2008:08:02 13:06:15
# 2                                   NaN              NaN                  NaN
# 3         Adobe Lightroom 5.5 (Windows)              NaN  2022:09:15 20:18:22
# 4                                   NaN              NaN                  NaN
#
#   exif_XResolution exif_YResolution
# 0            180.0            180.0
# 1              NaN              NaN
# 2              NaN              NaN
# 3            240.0            240.0
# 4              NaN              NaN

# %% [markdown]
# ## Task 2: Labeling and Annotation
#
# ### Goal
# Add descriptive labels and computed features to each image.
#
# ### What You Need to Do
#
# 1. **Extract color information** using KMeans clustering (Practical 2, Exercise 3):
#    - Find the 3-5 predominant colors in each image
#    - Store colors as RGB values and/or color names
#
# 2. **Determine image orientation**:
#    - Landscape (width > height)
#    - Portrait (height > width)
#    - Square (width ≈ height)
#
# 3. **Add category tags** (choose an approach):
#    - **Manual**: Create a simple interface to tag images
#    - **Automated**: Use image source categories/tags
#    - **Hybrid**: Start with source tags, allow user refinement
#    - voir yolo pour tags
#
# 4. **Classify image size**:
#    - Thumbnail: < 500px
#    - Medium: 500-1500px
#    - Large: > 1500px
#
# ### Expected Output
# - `data/images_labels.json` with enriched metadata:
# ```json
# {
#   "image_001.jpg": {
#     "predominant_colors": [[255, 128, 0], [0, 100, 200], [50, 50, 50]],
#     "color_names": ["orange", "blue", "gray"],
#     "orientation": "landscape",
#     "size_category": "medium",
#     "tags": ["nature", "sunset", "beach"]
#   }
# }
# ```
#
# ### Hints
# - Reuse your KMeans color extraction code from Practical 2
# - Consider using a color name mapping (RGB → color name)
# - Store all annotations in a structured JSON file
#
# ---

# %%
import os
import math
import json
import numpy
import webcolors
from PIL import Image
from sklearn.cluster import KMeans

# ── Config ────────────────────────────────────────────────────────────
IMAGE_DIR     = "images"
OUTPUT_FILE   = "data/images_labels.json"
N_COLORS      = 4
SUPPORTED_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".webp", ".tiff"}
os.makedirs(os.path.dirname(OUTPUT_FILE), exist_ok=True)

# ── RGB -> nom de couleur ─────────────────────────────────────────────
def rgb_to_color_name(rgb):
    rgb = tuple(int(v) for v in rgb)
    try:
        return webcolors.rgb_to_name(rgb)
    except ValueError:
        min_dist, closest_name = float("inf"), None
        for name in webcolors.names("css3"):
            ref  = tuple(webcolors.hex_to_rgb(webcolors.name_to_hex(name)))
            dist = math.sqrt(sum((a - b) ** 2 for a, b in zip(rgb, ref)))
            if dist < min_dist:
                min_dist, closest_name = dist, name
        return closest_name

# ── Helpers : orientation & taille ───────────────────────────────────
def get_orientation(width, height):
    if width > height:
        return "landscape"
    elif height > width:
        return "portrait"
    else:
        return "square"

def get_size_category(width, height):
    longest = max(width, height)
    if longest < 500:
        return "thumbnail"
    elif longest <= 1500:
        return "medium"
    else:
        return "large"

# ── Extraction KMeans ─────────────────────────────────────────────────
def extract_predominant_colors(image_path, n_colors=N_COLORS):
    imgfile  = Image.open(image_path).convert("RGB")
    numarray = numpy.array(imgfile.getdata(), numpy.uint8)
    if numarray.ndim == 1 or numarray.shape[1] != 3:
        numarray = numarray[:, :3]
    clusters = KMeans(n_clusters=n_colors, n_init=2, random_state=42)
    clusters.fit(numarray)
    npbins    = numpy.arange(0, n_colors + 1)
    histogram = numpy.histogram(clusters.labels_, bins=npbins)
    order     = numpy.argsort(-histogram[0])
    sorted_centers = clusters.cluster_centers_[order]
    rgb_list  = [[int(math.ceil(v)) for v in c] for c in sorted_centers]
    name_list = [rgb_to_color_name(c) for c in rgb_list]
    return rgb_list, name_list

# ── Collecte des chemins d'images ─────────────────────────────────────
all_labels  = {}
image_files = []
for root, dirs, files in os.walk(IMAGE_DIR):
    for f in files:
        if os.path.splitext(f)[1].lower() in SUPPORTED_EXT:
            image_files.append(os.path.join(root, f))

print(f"{len(image_files)} image(s) trouvée(s)\n")

# ── Boucle sur toutes les images ──────────────────────────────────────
for path in sorted(image_files):
    fname = os.path.basename(path)
    try:
        img  = Image.open(path).convert("RGB")
        w, h = img.size

        rgb_list, name_list = extract_predominant_colors(path)

        all_labels[fname] = {
            "predominant_colors": rgb_list,
            "color_names":        name_list,
            "orientation":        get_orientation(w, h),
            "size_category":      get_size_category(w, h),
        }
        print(f"  {fname:50s} ->  {name_list}  |  {get_orientation(w,h)}  |  {get_size_category(w,h)}")
    except Exception as e:
        print(f"  Erreur {fname} : {e}")

# ── Sauvegarde JSON ───────────────────────────────────────────────────
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(all_labels, f, indent=2, ensure_ascii=False)

print(f"\n{len(all_labels)} images sauvegardées -> {OUTPUT_FILE}")
# Out:
# 118 image(s) trouvée(s)
#
#   Aerial_view_of_Tashkent,_Uzbekistan.JPG            ->  ['dimgray', 'darkslategray', 'silver', 'lightslategray']  |  landscape  |  medium
#   Autobahnbau_in_Oyala.JPG                           ->  ['silver', 'rosybrown', 'dimgray', 'darkslategray']  |  landscape  |  large
#   BHA_Nassau,_Paradise_Island,_Atlantis_Bridge_001.jpg ->  ['steelblue', 'lightsteelblue', 'darkslategray', 'darkslategray']  |  landscape  |  large
#   Cherrapunji.jpg                                    ->  ['sienna', 'darkslategray', 'gray', 'snow']  |  portrait  |  medium
#   Ciudad_La_Plata_montage.jpg                        ->  ['lightgray', 'dimgray', 'black', 'steelblue']  |  portrait  |  large
#   Encarnación.jpg                                    ->  ['darkslategray', 'lightgray', 'slategray', 'darkgoldenrod']  |  portrait  |  large
#   Garocity.jpg                                       ->  ['darkgray', 'dimgray', 'whitesmoke', 'darkslategray']  |  landscape  |  medium
#   Jefferson_City.jpg                                 ->  ['darkslategray', 'dimgray', 'darkgray', 'gainsboro']  |  portrait  |  large
#   Kangar_(2019).jpg                                  ->  ['darkslategray', 'lavender', 'black', 'darkgray']  |  landscape  |  large
#   La_Guaira.jpg                                      ->  ['slategray', 'lightgray', 'lightblue', 'darkslategray']  |  landscape  |  medium
#   Liao_Shangjing_view_soutth.jpg                     ->  ['dimgray', 'lightsteelblue', 'gray', 'darkolivegreen']  |  landscape  |  large
#   Lintzoain.jpg                                      ->  ['dimgray', 'white', 'darkslategray', 'darkgray']  |  landscape  |  medium
#   Luxembourg_City_Hall_(54540726309).jpg             ->  ['cadetblue', 'dimgray', 'darkslategray', 'rosybrown']  |  landscape  |  large
#   Malabo_a_13-oct-01.jpg                             ->  ['dimgray', 'darkslategray', 'lightsteelblue', 'slategray']  |  landscape  |  large
#   Navajo_Nation_Council_Chambers_6809.jpg            ->  ['lavender', 'peru', 'mediumblue', 'maroon']  |  landscape  |  large
#   NileDeltaNapoleon01.jpg                            ->  ['snow', 'silver', 'black', 'gray']  |  landscape  |  large
#   Pungnap_Toseong.jpg                                ->  ['ghostwhite', 'darkolivegreen', 'gray', 'darkslategray']  |  landscape  |  medium
#   Reykjavík_5545_(cropped).JPG                       ->  ['lavender', 'black', 'darkgray', 'darkolivegreen']  |  landscape  |  large
#   Stone_Bridge_Skopje_4.jpg                          ->  ['lightsteelblue', 'dimgray', 'darkslategray', 'darkgray']  |  landscape  |  large
#   Tirana_from_South.jpg                              ->  ['slategray', 'darkslateblue', 'darkslategray', 'silver']  |  landscape  |  large
#   Twinmiracle.jpg                                    ->  ['tan', 'darkslategray', 'gray', 'lightsteelblue']  |  landscape  |  large
#   Vista_de_Alcanena.JPG                              ->  ['cornflowerblue', 'lightsteelblue', 'black', 'dimgray']  |  landscape  |  large
#   Краснодар.png                                      ->  ['gainsboro', 'darkslategray', 'dimgray', 'darkgray']  |  portrait  |  medium
#   몽촌토성.jpg                                           ->  ['darkolivegreen', 'black', 'gray', 'snow']  |  landscape  |  large
#   04.12_總統觀賞中華職棒比賽_Tsai_Ing-Wen_watching_baseball_with_Ah_Tsai.jpg ->  ['tan', 'dimgray', 'darkslategray', 'silver']  |  landscape  |  large
#   07.22_總統錄製Youtube影片.jpg                            ->  ['gainsboro', 'darkgray', 'dimgray', 'darkslategray']  |  square  |  large
#   2021_The_great_wall,_Leidsedwarstuin,_Asd_(4).jpg  ->  ['cadetblue', 'slategray', 'darkgray', 'darkslategray']  |  landscape  |  large
#   Arcturus_standing.jpg                              ->  ['maroon', 'tan', 'sienna', 'midnightblue']  |  portrait  |  medium
#   Brother_cream_in_stall.jpg                         ->  ['darkslategray', 'darkolivegreen', 'gray', 'silver']  |  portrait  |  large
#   Cat_at_Ayasofya.jpg                                ->  ['peru', 'saddlebrown', 'black', 'burlywood']  |  landscape  |  large
#   Crimean_Tom.jpg                                    ->  ['lavender', 'gray', 'black', 'darkolivegreen']  |  landscape  |  medium
#   Fat_cat,_asleep_(319313958).jpg                    ->  ['darkgray', 'gray', 'darkolivegreen', 'black']  |  landscape  |  large
#   Gladstone_a_year_in_Treasury_(1).jpg               ->  ['darkgray', 'linen', 'darkslategray', 'dimgray']  |  landscape  |  medium
#   Hank_Political_Poster.jpg                          ->  ['midnightblue', 'cadetblue', 'navajowhite', 'crimson']  |  portrait  |  large
#   India_the_Cat_Miss_Beazley_and_Barney_Halloween_2007_(cropped).jpg ->  ['gray', 'darkslategray', 'tan', 'tomato']  |  landscape  |  medium
#   IndioCat.jpg                                       ->  ['black', 'rosybrown', 'thistle', 'dimgray']  |  portrait  |  medium
#   Kkongkkong,_September_10,_2020.jpg                 ->  ['darkolivegreen', 'black', 'gray', 'gainsboro']  |  landscape  |  large
#   Larry_Chief_Mouser.jpg                             ->  ['black', 'saddlebrown', 'antiquewhite', 'gray']  |  landscape  |  large
#   Lil-Bub-2013_(cropped).jpg                         ->  ['darkslategray', 'darkslategray', 'gray', 'silver']  |  landscape  |  thumbnail
#   Mayor_Stubbs.jpg                                   ->  ['rosybrown', 'dimgray', 'lightgray', 'darkslategray']  |  landscape  |  medium
#   Mittens_the_Cat_2018.jpg                           ->  ['darkgray', 'gray', 'gainsboro', 'darkslategray']  |  landscape  |  medium
#   Rescue_of_a_cat_in_Borodianka,_2_May_2022_(4).jpg  ->  ['black', 'darkgray', 'gray', 'darkolivegreen']  |  landscape  |  thumbnail
#   Socks_the_Cat_Explores.jpg                         ->  ['darkslategray', 'black', 'dimgray', 'silver']  |  landscape  |  large
#   Station-Master_Tama.JPG                            ->  ['dimgray', 'lightgray', 'darkslategray', 'brown']  |  landscape  |  medium
#   UCDavisCheeto.jpg                                  ->  ['darkslategray', 'darkgray', 'gray', 'darkslategray']  |  portrait  |  medium
#   WhiteHousePets,_ValentinesDay2007.jpg              ->  ['black', 'brown', 'darkslategray', 'indianred']  |  landscape  |  medium
#   Наталия_Ушакова._1927.jpg                          ->  ['darkgray', 'dimgray', 'darkslategray', 'gray']  |  portrait  |  thumbnail
#   Наталка_Діденко_з_котом_Апельмоном.jpg             ->  ['tan', 'sienna', 'darkslategray', 'whitesmoke']  |  portrait  |  large
#   オシンコシンの滝の猫の昼寝.jpg                                  ->  ['black', 'antiquewhite', 'darkgray', 'darkolivegreen']  |  landscape  |  large
#   Adenium_Obesum_Flower_Side_Macro_Mar22_D72_23052-58_ZS_P.jpg ->  ['gray', 'silver', 'crimson', 'darkslategray']  |  landscape  |  large
#   Apricot_blossom.jpg                                ->  ['darkgray', 'lavender', 'black', 'gray']  |  landscape  |  large
#   Butchart_Gardens_(145582500).jpg                   ->  ['black', 'sandybrown', 'darkolivegreen', 'darkgoldenrod']  |  landscape  |  large
#   Close-up_Eucalyptus_Flower_Ooty_Sep25_A7CR_07608-22_zsp.jpg ->  ['black', 'tan', 'gray', 'darkolivegreen']  |  square  |  large
#   Erysimum_cheiri_gold_garden_flowers.jpg            ->  ['darkorange', 'darkslategray', 'saddlebrown', 'dimgray']  |  landscape  |  large
#   Flor_de_Palma_Entre_los_llanos_y_Sierra_Hermosa,_Coahuila_-_panoramio.jpg ->  ['darkslategray', 'dimgray', 'darkseagreen', 'gainsboro']  |  landscape  |  large
#   Flower_Water_Apple_Valparai_Feb26_A7CR_10135.jpg   ->  ['black', 'darkslategray', 'dimgray', 'darkgray']  |  square  |  large
#   Flowers_Closeup_Coffee_Robusta_Suntikoppa_Apr24_A7C_10826.jpg ->  ['darkolivegreen', 'darkslategray', 'lightgray', 'olive']  |  landscape  |  large
#   Formosa_lily,_Nagai_Park,_Osaka.jpg                ->  ['darkolivegreen', 'black', 'silver', 'gray']  |  portrait  |  large
#   Frühlings_Enzian_Gentiana_verna_03.JPG             ->  ['black', 'royalblue', 'darkolivegreen', 'midnightblue']  |  landscape  |  large
#   Karakaftja.jpg                                     ->  ['gray', 'dimgray', 'silver', 'darkslategray']  |  portrait  |  large
#   LiliumBulbiferumCroceumBologna.jpg                 ->  ['black', 'darkslategray', 'sandybrown', 'chocolate']  |  landscape  |  large
#   Lilium_michiganense_2.jpg                          ->  ['darkolivegreen', 'darkslategray', 'rosybrown', 'lightblue']  |  portrait  |  medium
#   Ohitashi_of_nanohana_2015.jpg                      ->  ['darkolivegreen', 'antiquewhite', 'darkkhaki', 'darkslategray']  |  landscape  |  large
#   Purple_puffer_(2257511230).jpg                     ->  ['darkkhaki', 'gainsboro', 'black', 'purple']  |  portrait  |  medium
#   Red_Carnation_Flower.jpg                           ->  ['firebrick', 'black', 'darkolivegreen', 'peru']  |  landscape  |  large
#   Tanacetum_parthenium_-_Köhler–s_Medizinal-Pflanzen-036.jpg ->  ['snow', 'darkolivegreen', 'darkgreen', 'darkgray']  |  portrait  |  medium
#   Ukiyoe_calendar_June_2010_hokusai_--_yuri.jpg      ->  ['darkgray', 'navajowhite', 'darkslategray', 'sandybrown']  |  landscape  |  thumbnail
#   Ulex_europaeus3.jpg                                ->  ['goldenrod', 'darkolivegreen', 'olive', 'gold']  |  landscape  |  medium
#   Aouille_Tseque_and_Glacier_de_l'Aiguillette.jpg    ->  ['darkslategray', 'steelblue', 'cornflowerblue', 'lightsteelblue']  |  landscape  |  large
#   Arollagletscher.jpg                                ->  ['darkslategray', 'gray', 'black', 'gainsboro']  |  portrait  |  medium
#   Becs_de_Bosson_depuis_le_Pas_de_Lona.jpg           ->  ['darkcyan', 'gray', 'darkolivegreen', 'tan']  |  landscape  |  large
#   Besso_-_Blanc_de_Moming_-_Dent_Blanche.jpg         ->  ['steelblue', 'darkslateblue', 'silver', 'darkslategray']  |  landscape  |  large
#   Bigerhorn-balfrin-01.jpg                           ->  ['gray', 'steelblue', 'darkslategray', 'silver']  |  landscape  |  large
#   Corbassiere4.JPG                                   ->  ['lightgray', 'darkslategray', 'gray', 'steelblue']  |  landscape  |  large
#   Drehrestaurant_Mittelallalin.jpg                   ->  ['steelblue', 'dimgray', 'darkslategray', 'lavender']  |  landscape  |  large
#   Egginer_vom_Mittagshorn.JPG                        ->  ['cornflowerblue', 'black', 'lightsteelblue', 'dimgray']  |  landscape  |  large
#   FluchthornVSFromE.jpg                              ->  ['steelblue', 'gray', 'dimgray', 'gainsboro']  |  portrait  |  large
#   Funivia_Rote_Nase_alt.JPG                          ->  ['lavender', 'lightslategray', 'darkslateblue', 'darkslategray']  |  landscape  |  large
#   Hohtälli.JPG                                       ->  ['dimgray', 'steelblue', 'darkgray', 'darkslategray']  |  landscape  |  medium
#   Jagerhorn0001.jpg                                  ->  ['dimgray', 'lightgray', 'darkslategray', 'lightslategray']  |  landscape  |  medium
#   Les_Diablons_depuis_Sorebois.jpg                   ->  ['gainsboro', 'teal', 'darkslategray', 'darkgray']  |  landscape  |  large
#   MontRogneux.jpeg                                   ->  ['silver', 'darkslategray', 'dimgray', 'darkgray']  |  landscape  |  large
#   Moosalp_Bonigersee.jpg                             ->  ['black', 'dimgray', 'cadetblue', 'lightsteelblue']  |  landscape  |  medium
#   Otemma.jpg                                         ->  ['gainsboro', 'steelblue', 'darkgray', 'midnightblue']  |  landscape  |  large
#   Piolone0001.jpg                                    ->  ['darkslategray', 'darkolivegreen', 'slategray', 'silver']  |  landscape  |  medium
#   Plattjen.jpg                                       ->  ['lavender', 'lightslategray', 'silver', 'dimgray']  |  landscape  |  large
#   Roc_d'Orzival.jpg                                  ->  ['cornflowerblue', 'darkslategray', 'dimgray', 'darkgray']  |  landscape  |  large
#   Saas-Grund_mit_Plattjen.jpg                        ->  ['darkslategray', 'darkolivegreen', 'darkseagreen', 'aliceblue']  |  landscape  |  large
#   SchoenbielhornFromSE.jpg                           ->  ['steelblue', 'darkolivegreen', 'dimgray', 'lightgray']  |  landscape  |  large
#   Seetalhorn.JPG                                     ->  ['skyblue', 'dimgray', 'darkslategray', 'gainsboro']  |  landscape  |  large
#   SpechhornFromNW.JPG                                ->  ['lightslategray', 'cornflowerblue', 'dimgray', 'powderblue']  |  portrait  |  large
#   UlrichshornFromSW.jpg                              ->  ['lightslategray', 'snow', 'darkslategray', 'silver']  |  landscape  |  large
#   Wallis_Stellihorn_mg-k.jpg                         ->  ['darkslategray', 'slategray', 'silver', 'midnightblue']  |  landscape  |  medium
#   Bearded_Mountaineer_(Oreonympha_nobilis).jpg       ->  ['darkgray', 'dimgray', 'silver', 'darkslategray']  |  portrait  |  large
#   Black-tailed_Trainbearer_(Lesbia_victoriae).jpg    ->  ['darkslategray', 'dimgray', 'silver', 'darkseagreen']  |  portrait  |  medium
#   Blue-bearded_Helmetcrest.jpg                       ->  ['black', 'seashell', 'darkolivegreen', 'darkkhaki']  |  landscape  |  large
#   ChaetocercusBurmeisteriKeulemans.jpg               ->  ['snow', 'gray', 'darkgray', 'darkslategray']  |  portrait  |  large
#   Great_sapphirewing_(Pterophanes_cyanopterus_caeruleus)_male_Caldas.jpg ->  ['rosybrown', 'dimgray', 'darkslategray', 'silver']  |  landscape  |  large
#   Loddigesia_mirabilis_114707728.jpg                 ->  ['darkolivegreen', 'darkslategray', 'gray', 'silver']  |  landscape  |  large
#   Male_Blue-chinned_Sapphire_(Chlorestes_notatus).jpg ->  ['darkslategray', 'darkolivegreen', 'dimgray', 'darkseagreen']  |  portrait  |  large
#   Maleo_bird.PNG                                     ->  ['ghostwhite', 'wheat', 'darkslategray', 'indianred']  |  landscape  |  large
#   Mountain_velvetbreast_(Lafresnaya_lafresnayi_longirostris)_male_Caldas.jpg ->  ['tan', 'darkkhaki', 'dimgray', 'darkslategray']  |  square  |  large
#   Numida_meleagris_-Kruger_National_Park,_South_Africa-8a.jpg ->  ['rosybrown', 'dimgray', 'darkolivegreen', 'black']  |  landscape  |  large
#   Oxypogon_guerinii_236915214.jpg                    ->  ['gray', 'dimgray', 'darkslategray', 'darkgray']  |  landscape  |  medium
#   Oxypogon_guerinii_female.jpg                       ->  ['darkslategray', 'dimgray', 'rosybrown', 'silver']  |  landscape  |  large
#   Oxypogon_guerinii_lindenii.jpg                     ->  ['white', 'black', 'dimgray', 'darkgray']  |  portrait  |  large
#   Oxypogon_stuebelii_-_Buffy_Helmetcrest_-_Colibrí_Chivito_del_Ruiz.jpg ->  ['darkolivegreen', 'darkgray', 'gray', 'darkslategray']  |  portrait  |  medium
#   Picaflor_de_arica.jpg                              ->  ['black', 'darkolivegreen', 'darkkhaki', 'beige']  |  portrait  |  large
#   Scaly-breasted_Hummingbird_-_Sarapiqui_-_Costa_Rica_S4E0291_(26084747394).jpg ->  ['darkslategray', 'olivedrab', 'maroon', 'red']  |  portrait  |  medium
#   Schistes_albogularis_240980514_(cropped).jpg       ->  ['gray', 'darkolivegreen', 'darkslategray', 'darkgray']  |  landscape  |  medium
#   Schistes_geoffroyi_(Pico_de_cuña)_(22653616465).jpg ->  ['olivedrab', 'gray', 'darkolivegreen', 'silver']  |  landscape  |  large
#   Stavenn_Maleo.jpg                                  ->  ['black', 'silver', 'darkolivegreen', 'gray']  |  portrait  |  thumbnail
#   Stephanoxis_loddigesii_244152090.jpg               ->  ['darkolivegreen', 'olivedrab', 'darkolivegreen', 'darkkhaki']  |  portrait  |  large
#   Taoniscus.jpg                                      ->  ['darkslategray', 'darkolivegreen', 'gray', 'silver']  |  portrait  |  thumbnail
#   Thaumastura_cora_188341541.jpg                     ->  ['darkslategray', 'darkolivegreen', 'gray', 'gainsboro']  |  portrait  |  medium
#   Violet-headed_Hummingbird_(Klais_guimeti)_2015-06-14_(1)_(40283795752).jpg ->  ['darkolivegreen', 'darkgreen', 'gray', 'silver']  |  landscape  |  large
#   White-bellied_Mountain-gem_(Oreopyra_hemileucus).jpg ->  ['darkolivegreen', 'darkolivegreen', 'gray', 'wheat']  |  portrait  |  thumbnail
#   Área_de_Proteção_Ambiental_Serra_Dona_Francisca_-_Luiz_Alves_(108).jpg ->  ['silver', 'olivedrab', 'darkolivegreen', 'gray']  |  landscape  |  large
#
# 118 images sauvegardées -> data/images_labels.json

# %%
# !python3 -m pip install ultralytics ipywidgets --break-system-packages
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/homebrew/lib/python3.14/site-packages (from ultralytics) (2.4.3)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/homebrew/lib/python3.14/site-packages (from ultralytics) (3.10.8)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/homebrew/lib/python3.14/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /opt/homebrew/lib/python3.14/site-packages (from ultralytics) (12.1.1)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Downloading pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting requests>=2.23.0 (from ultralytics)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting scipy>=1.4.1 (from ultralytics)
#   Downloading scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.11.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.26.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Collecting psutil>=5.8.0 (from ultralytics)
#   Downloading psutil-7.2.2-cp36-abi3-macosx_11_0_arm64.whl.metadata (22 kB)
# Collecting polars>=0.20.0 (from ultralytics)
#   Downloading polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Collecting comm>=0.1.3 (from ipywidgets)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipython>=6.1.0 (from ipywidgets)
#   Downloading ipython-9.12.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting traitlets>=4.3.1 (from ipywidgets)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Collecting decorator>=5.1.0 (from ipython>=6.1.0->ipywidgets)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=6.1.0->ipywidgets)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=6.1.0->ipywidgets)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline>=0.1.6 (from ipython>=6.1.0->ipywidgets)
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting pexpect>4.6 (from ipython>=6.1.0->ipywidgets)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.14.0 (from ipython>=6.1.0->ipywidgets)
#   Downloading pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data>=0.6.0 (from ipython>=6.1.0->ipywidgets)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets)
#   Downloading wcwidth-0.6.0-py3-none-any.whl.metadata (30 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets)
#   Downloading parso-0.8.6-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/lib/python3.14/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Collecting ptyprocess>=0.5 (from pexpect>4.6->ipython>=6.1.0->ipywidgets)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting polars-runtime-32==1.40.1 (from polars>=0.20.0->ultralytics)
#   Downloading polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.23.0->ultralytics)
#   Downloading charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->ultralytics)
#   Downloading idna-3.13-py3-none-any.whl.metadata (8.0 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.23.0->ultralytics)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2023.5.7 (from requests>=2.23.0->ultralytics)
#   Downloading certifi-2026.4.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets)
#   Downloading asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch>=1.8.0->ultralytics)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting setuptools<82 (from torch>=1.8.0->ultralytics)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch>=1.8.0->ultralytics)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.0->ultralytics)
#   Downloading markupsafe-3.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Downloading ultralytics-8.4.41-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 21.3 MB/s  0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 31.8 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 41.6 MB/s  0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading ipython-9.12.0-py3-none-any.whl (625 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.7/625.7 kB 23.4 MB/s  0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.1 MB/s  0:00:00
# Downloading parso-0.8.6-py2.py3-none-any.whl (106 kB)
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading polars-1.40.1-py3-none-any.whl (828 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 828.7/828.7 kB 28.0 MB/s  0:00:00
# Downloading polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl (46.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 MB 35.6 MB/s  0:00:01 36.7 MB/s eta 0:00:01
# Downloading psutil-7.2.2-cp36-abi3-macosx_11_0_arm64.whl (129 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pygments-2.20.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.4 MB/s  0:00:00
# Downloading pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl (173 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.7-cp314-cp314-macosx_10_15_universal2.whl (309 kB)
# Downloading idna-3.13-py3-none-any.whl (68 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.4.22-py3-none-any.whl (135 kB)
# Downloading scipy-1.17.1-cp314-cp314-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 26.0 MB/s  0:00:00 27.1 MB/s eta 0:00:01
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.1-py3-none-any.whl (27 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading torch-2.11.0-cp314-cp314-macosx_11_0_arm64.whl (80.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 5.4 MB/s  0:00:15 eta 0:00:010:00:01m
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.3 MB/s  0:00:00
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.5 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 11.5 MB/s  0:00:00 12.1 MB/s eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 9.2 MB/s  0:00:00
# Downloading torchvision-0.26.0-cp314-cp314-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.7 MB/s  0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp314-cp314-macosx_11_0_arm64.whl (12 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.6.0-py3-none-any.whl (94 kB)
# Installing collected packages: pure-eval, ptyprocess, mpmath, widgetsnbextension, wcwidth, urllib3, typing-extensions, traitlets, sympy, setuptools, scipy, pyyaml, pygments, psutil, polars-runtime-32, pexpect, parso, networkx, MarkupSafe, jupyterlab_widgets, idna, fsspec, filelock, executing, decorator, comm, charset_normalizer, certifi, asttokens, stack_data, requests, prompt_toolkit, polars, matplotlib-inline, jinja2, jedi, ipython-pygments-lexers, torch, ipython, ultralytics-thop, torchvision, ipywidgets, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43/43 [ultralytics]m [ultralytics]m [torchvision]s]toolkit]
# Successfully installed MarkupSafe-3.0.3 asttokens-3.0.1 certifi-2026.4.22 charset_normalizer-3.4.7 comm-0.2.3 decorator-5.2.1 executing-2.2.1 filelock-3.29.0 fsspec-2026.3.0 idna-3.13 ipython-9.12.0 ipython-pygments-lexers-1.1.1 ipywidgets-8.1.8 jedi-0.19.2 jinja2-3.1.6 jupyterlab_widgets-3.0.16 matplotlib-inline-0.2.1 mpmath-1.3.0 networkx-3.6.1 parso-0.8.6 pexpect-4.9.0 polars-1.40.1 polars-runtime-32-1.40.1 prompt_toolkit-3.0.52 psutil-7.2.2 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.20.0 pyyaml-6.0.3 requests-2.33.1 scipy-1.17.1 setuptools-81.0.0 stack_data-0.6.3 sympy-1.14.0 torch-2.11.0 torchvision-0.26.0 traitlets-5.14.3 typing-extensions-4.15.0 ultralytics-8.4.41 ultralytics-thop-2.0.18 urllib3-2.6.3 wcwidth-0.6.0 widgetsnbextension-4.0.15

# %%
import sys
# !{sys.executable} -m pip install ultralytics ipywidgets --break-system-packages
# Out:
# Collecting ultralytics
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: numpy>=1.23.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (2.2.5)
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (4.13.0.92)
# Requirement already satisfied: pillow>=7.1.2 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (1.15.3)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.26.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (5.5 kB)
# Requirement already satisfied: psutil>=5.8.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ultralytics) (7.0.0)
# Collecting polars>=0.20.0 (from ultralytics)
#   Using cached polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics)
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: comm>=0.1.3 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipywidgets) (9.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Collecting polars-runtime-32==1.40.1 (from polars>=0.20.0->ultralytics)
#   Using cached polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/opt/certifi/lib/python3.13/site-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: setuptools<82 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (79.0.1)
# Collecting sympy>=1.13.3 (from torch>=1.8.0->ultralytics)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch>=1.8.0->ultralytics)
#   Using cached fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.0->ultralytics)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: executing>=1.2.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in /opt/homebrew/Cellar/jupyterlab/4.4.1_1/libexec/lib/python3.13/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Using cached ultralytics-8.4.41-py3-none-any.whl (1.2 MB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Using cached polars-1.40.1-py3-none-any.whl (828 kB)
# Using cached polars_runtime_32-1.40.1-cp310-abi3-macosx_11_0_arm64.whl (46.4 MB)
# Downloading torch-2.11.0-cp313-cp313-macosx_11_0_arm64.whl (80.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 MB 38.6 MB/s  0:00:02 eta 0:00:010:00:01
# Using cached fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading torchvision-0.26.0-cp313-cp313-macosx_12_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.4 MB/s  0:00:00
# Using cached ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Installing collected packages: mpmath, widgetsnbextension, sympy, polars-runtime-32, jupyterlab_widgets, fsspec, filelock, torch, polars, ultralytics-thop, torchvision, ipywidgets, ultralytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [ultralytics]m━━━ 12/13 [ultralytics]
# Successfully installed filelock-3.29.0 fsspec-2026.3.0 ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 mpmath-1.3.0 polars-1.40.1 polars-runtime-32-1.40.1 sympy-1.14.0 torch-2.11.0 torchvision-0.26.0 ultralytics-8.4.41 ultralytics-thop-2.0.18 widgetsnbextension-4.0.15

# %%
import os
import math
import json
import numpy
import webcolors
from PIL import Image
from sklearn.cluster import KMeans
from ultralytics import YOLO

# ── Config ────────────────────────────────────────────────────────────
IMAGE_DIR     = "images"
OUTPUT_FILE   = "data/images_labels.json"
N_COLORS      = 4
SUPPORTED_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".webp", ".tiff"}
os.makedirs(os.path.dirname(OUTPUT_FILE), exist_ok=True)

# ── Chargement des catégories depuis images_metadata.json ─────────────
with open("data/images_metadata.json", "r", encoding="utf-8") as f:
    all_metadata = json.load(f)
fname_to_category = {item["filename"]: item["category"] for item in all_metadata}

# ── Modèles YOLO ──────────────────────────────────────────────────────
yolo_model     = YOLO("yolov8m.pt")
classify_model = YOLO("yolov8m-cls.pt")

def get_yolo_tags(image_path, conf=0.25, top_k=3):
    results = yolo_model(image_path, verbose=False, conf=conf)
    detection_tags = list({yolo_model.names[int(c)] for r in results for c in r.boxes.cls})
    cls_results    = classify_model(image_path, verbose=False)
    classify_tags  = [classify_model.names[i] for i in cls_results[0].probs.top5[:top_k]]
    return list(dict.fromkeys(detection_tags + classify_tags))

# ── RGB -> nom de couleur ─────────────────────────────────────────────
def rgb_to_color_name(rgb):
    rgb = tuple(int(v) for v in rgb)
    try:
        return webcolors.rgb_to_name(rgb)
    except ValueError:
        min_dist, closest_name = float("inf"), None
        for name in webcolors.names("css3"):
            ref  = tuple(webcolors.hex_to_rgb(webcolors.name_to_hex(name)))
            dist = math.sqrt(sum((a - b) ** 2 for a, b in zip(rgb, ref)))
            if dist < min_dist:
                min_dist, closest_name = dist, name
        return closest_name

# ── Helpers : orientation & taille ───────────────────────────────────
def get_orientation(width, height):
    if width > height:
        return "landscape"
    elif height > width:
        return "portrait"
    else:
        return "square"

def get_size_category(width, height):
    longest = max(width, height)
    if longest < 500:
        return "thumbnail"
    elif longest <= 1500:
        return "medium"
    else:
        return "large"

# ── Extraction KMeans ─────────────────────────────────────────────────
def extract_predominant_colors(image_path, n_colors=N_COLORS):
    imgfile  = Image.open(image_path).convert("RGB")
    numarray = numpy.array(imgfile.getdata(), numpy.uint8)
    if numarray.ndim == 1 or numarray.shape[1] != 3:
        numarray = numarray[:, :3]
    clusters = KMeans(n_clusters=n_colors, n_init=2, random_state=42)
    clusters.fit(numarray)
    npbins    = numpy.arange(0, n_colors + 1)
    histogram = numpy.histogram(clusters.labels_, bins=npbins)
    order     = numpy.argsort(-histogram[0])
    sorted_centers = clusters.cluster_centers_[order]
    rgb_list  = [[int(math.ceil(v)) for v in c] for c in sorted_centers]
    name_list = [rgb_to_color_name(c) for c in rgb_list]
    return rgb_list, name_list

# ── Collecte des chemins d'images ─────────────────────────────────────
all_labels  = {}
image_files = []
for root, dirs, files in os.walk(IMAGE_DIR):
    for f in files:
        if os.path.splitext(f)[1].lower() in SUPPORTED_EXT:
            image_files.append(os.path.join(root, f))

print(f"{len(image_files)} image(s) trouvée(s)\n")

# ── Boucle sur toutes les images ──────────────────────────────────────
for path in sorted(image_files):
    fname = os.path.basename(path)
    try:
        img  = Image.open(path).convert("RGB")
        w, h = img.size

        rgb_list, name_list = extract_predominant_colors(path)

        # Tags YOLO + catégorie garantie
        tags         = get_yolo_tags(path)
        category_tag = fname_to_category.get(fname)
        if category_tag and category_tag not in tags:
            tags.append(category_tag)

        all_labels[fname] = {
            "predominant_colors": rgb_list,
            "color_names":        name_list,
            "orientation":        get_orientation(w, h),
            "size_category":      get_size_category(w, h),
            "tags":               tags,
        }
        print(f"  {fname:50s} ->  {get_orientation(w,h)}  |  {get_size_category(w,h)}  |  {tags}")
    except Exception as e:
        print(f"  Erreur {fname} : {e}")

# ── Sauvegarde JSON ───────────────────────────────────────────────────
with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
    json.dump(all_labels, f, indent=2, ensure_ascii=False)

print(f"\n{len(all_labels)} images sauvegardées -> {OUTPUT_FILE}")
# Out:
# 118 image(s) trouvée(s)
#
#   Aerial_view_of_Tashkent,_Uzbekistan.JPG            ->  landscape  |  medium  |  ['seashore', 'wing', 'valley', 'capitales']
#   Autobahnbau_in_Oyala.JPG                           ->  landscape  |  large  |  ['truck', 'person', 'bench', 'snowplow', 'alp', 'jeep', 'capitales']
#   BHA_Nassau,_Paradise_Island,_Atlantis_Bridge_001.jpg ->  landscape  |  large  |  ['boat', 'seashore', 'catamaran', 'speedboat', 'capitales']
#   Cherrapunji.jpg                                    ->  portrait  |  medium  |  ['book_jacket', 'street_sign', 'pill_bottle', 'capitales']
#   Ciudad_La_Plata_montage.jpg                        ->  portrait  |  large  |  ['car', 'person', 'dog', 'church', 'monastery', 'mosque', 'capitales']
#   Encarnación.jpg                                    ->  portrait  |  large  |  ['person', 'clock', 'cab', 'church', 'fountain', 'capitales']
#   Garocity.jpg                                       ->  landscape  |  medium  |  ['horse', 'car', 'palace', 'picket_fence', 'monastery', 'capitales']
#   Jefferson_City.jpg                                 ->  portrait  |  large  |  ['car', 'dome', 'liner', 'dock', 'capitales']
#   Kangar_(2019).jpg                                  ->  landscape  |  large  |  ['person', 'car', 'grocery_store', 'traffic_light', 'fire_engine', 'capitales']
#   La_Guaira.jpg                                      ->  landscape  |  medium  |  ['breakwater', 'seashore', 'lakeside', 'capitales']
#   Liao_Shangjing_view_soutth.jpg                     ->  landscape  |  large  |  ['valley', 'hay', 'stone_wall', 'capitales']
#   Lintzoain.jpg                                      ->  landscape  |  medium  |  ['monastery', 'alp', 'promontory', 'capitales']
#   Luxembourg_City_Hall_(54540726309).jpg             ->  landscape  |  large  |  ['potted plant', 'palace', 'monastery', 'cinema', 'capitales']
#   Malabo_a_13-oct-01.jpg                             ->  landscape  |  large  |  ['boat', 'lakeside', 'seashore', 'promontory', 'capitales']
#   Navajo_Nation_Council_Chambers_6809.jpg            ->  landscape  |  large  |  ['car', 'bird', 'bench', 'palace', 'church', 'monastery', 'capitales']
#   NileDeltaNapoleon01.jpg                            ->  landscape  |  large  |  ['shower_curtain', 'bath_towel', 'toilet_tissue', 'capitales']
#   Pungnap_Toseong.jpg                                ->  landscape  |  medium  |  ['person', 'car', 'alp', 'stone_wall', 'lakeside', 'capitales']
#   Reykjavík_5545_(cropped).JPG                       ->  landscape  |  large  |  ['car', 'dome', 'palace', 'lakeside', 'capitales']
#   Stone_Bridge_Skopje_4.jpg                          ->  landscape  |  large  |  ['horse', 'potted plant', 'person', 'bench', 'palace', 'fountain', 'seashore', 'capitales']
#   Tirana_from_South.jpg                              ->  landscape  |  large  |  ['lakeside', 'alp', 'seashore', 'capitales']
#   Twinmiracle.jpg                                    ->  landscape  |  large  |  ['suitcase', 'lumbermill', 'dam', 'maze', 'capitales']
#   Vista_de_Alcanena.JPG                              ->  landscape  |  large  |  ['mobile_home', 'lakeside', 'recreational_vehicle', 'capitales']
#   Краснодар.png                                      ->  portrait  |  medium  |  ['car', 'train', 'fountain', 'church', 'palace', 'capitales']
#   몽촌토성.jpg                                           ->  landscape  |  large  |  ['stone_wall', 'valley', 'megalith', 'capitales']
#   04.12_總統觀賞中華職棒比賽_Tsai_Ing-Wen_watching_baseball_with_Ah_Tsai.jpg ->  landscape  |  large  |  ['chair', 'tv', 'person', 'cat', 'sports ball', 'frisbee', 'television', 'screen', 'mouse']
#   07.22_總統錄製Youtube影片.jpg                            ->  square  |  large  |  ['cat', 'Egyptian_cat', 'tabby', 'tiger_cat']
#   2021_The_great_wall,_Leidsedwarstuin,_Asd_(4).jpg  ->  landscape  |  large  |  ['bird', 'cat', 'book_jacket', 'ruffed_grouse', 'bulbul']
#   Arcturus_standing.jpg                              ->  portrait  |  medium  |  ['person', 'cat', 'tiger_cat', 'Egyptian_cat', 'leopard']
#   Brother_cream_in_stall.jpg                         ->  portrait  |  large  |  ['bottle', 'cat', 'book', 'tiger_cat', 'refrigerator', 'toyshop']
#   Cat_at_Ayasofya.jpg                                ->  landscape  |  large  |  ['cat', 'Egyptian_cat', 'tabby', 'throne']
#   Crimean_Tom.jpg                                    ->  landscape  |  medium  |  ['cat', 'Egyptian_cat', 'tabby', 'tiger_cat']
#   Fat_cat,_asleep_(319313958).jpg                    ->  landscape  |  large  |  ['toilet', 'cat', 'screen', 'monitor', 'television']
#   Gladstone_a_year_in_Treasury_(1).jpg               ->  landscape  |  medium  |  ['dining table', 'chair', 'cat', 'book', 'Egyptian_cat', 'tabby', 'tub']
#   Hank_Political_Poster.jpg                          ->  portrait  |  large  |  ['kite', 'comic_book', 'book_jacket', 'binder', 'cat']
#   India_the_Cat_Miss_Beazley_and_Barney_Halloween_2007_(cropped).jpg ->  landscape  |  medium  |  ['frisbee', 'cat', 'sports ball', 'Brabancon_griffon', 'bucket', 'pug']
#   IndioCat.jpg                                       ->  portrait  |  medium  |  ['cat', 'Egyptian_cat', 'tabby', 'tub']
#   Kkongkkong,_September_10,_2020.jpg                 ->  landscape  |  large  |  ['person', 'cat', 'Chihuahua', 'papillon', 'toy_terrier']
#   Larry_Chief_Mouser.jpg                             ->  landscape  |  large  |  ['tie', 'chair', 'cat', 'Egyptian_cat', 'tabby', 'tiger_cat']
#   Lil-Bub-2013_(cropped).jpg                         ->  landscape  |  thumbnail  |  ['dog', 'cat', 'tabby', 'Persian_cat', 'Egyptian_cat']
#   Mayor_Stubbs.jpg                                   ->  landscape  |  medium  |  ['umbrella', 'potted plant', 'cat', 'tiger_cat', 'Egyptian_cat', 'tabby']
#   Mittens_the_Cat_2018.jpg                           ->  landscape  |  medium  |  ['fire hydrant', 'cat', 'lynx', 'tiger_cat', 'carton']
#   Rescue_of_a_cat_in_Borodianka,_2_May_2022_(4).jpg  ->  landscape  |  thumbnail  |  ['person', 'cat', 'Pekinese', 'Angora', 'Persian_cat']
#   Socks_the_Cat_Explores.jpg                         ->  landscape  |  large  |  ['cat', 'pool_table', 'chest', 'crib']
#   Station-Master_Tama.JPG                            ->  landscape  |  medium  |  ['couch', 'teddy bear', 'cat', 'tabby', 'tiger_cat', 'bow_tie']
#   UCDavisCheeto.jpg                                  ->  portrait  |  medium  |  ['cat', 'Egyptian_cat', 'tiger_cat', 'tabby']
#   WhiteHousePets,_ValentinesDay2007.jpg              ->  landscape  |  medium  |  ['tie', 'dog', 'Scotch_terrier', 'miniature_schnauzer', 'giant_schnauzer', 'cat']
#   Наталия_Ушакова._1927.jpg                          ->  portrait  |  thumbnail  |  ['person', 'cat', 'miniature_pinscher', 'Chihuahua', 'Boston_bull']
#   Наталка_Діденко_з_котом_Апельмоном.jpg             ->  portrait  |  large  |  ['person', 'chair', 'cat', 'Persian_cat', 'tiger_cat', 'Egyptian_cat']
#   オシンコシンの滝の猫の昼寝.jpg                                  ->  landscape  |  large  |  ['cat', 'tiger_cat', 'Egyptian_cat', 'tabby']
#   Adenium_Obesum_Flower_Side_Macro_Mar22_D72_23052-58_ZS_P.jpg ->  landscape  |  large  |  ['bird', 'strawberry', 'hummingbird', 'hip', 'flower']
#   Apricot_blossom.jpg                                ->  landscape  |  large  |  ['bee', 'ant', 'hip', 'flower']
#   Butchart_Gardens_(145582500).jpg                   ->  landscape  |  large  |  ['bell_pepper', 'rapeseed', "yellow_lady's_slipper", 'flower']
#   Close-up_Eucalyptus_Flower_Ooty_Sep25_A7CR_07608-22_zsp.jpg ->  square  |  large  |  ['daisy', 'swab', 'sea_anemone', 'flower']
#   Erysimum_cheiri_gold_garden_flowers.jpg            ->  landscape  |  large  |  ['orange', 'ant', 'greenhouse', 'rapeseed', 'flower']
#   Flor_de_Palma_Entre_los_llanos_y_Sierra_Hermosa,_Coahuila_-_panoramio.jpg ->  landscape  |  large  |  ['sulphur-crested_cockatoo', 'fountain', 'daisy', 'flower']
#   Flower_Water_Apple_Valparai_Feb26_A7CR_10135.jpg   ->  square  |  large  |  ['umbrella', 'buckeye', 'cardoon', 'sea_urchin', 'flower']
#   Flowers_Closeup_Coffee_Robusta_Suntikoppa_Apr24_A7C_10826.jpg ->  landscape  |  large  |  ['potted plant', 'daisy', 'earthstar', 'pinwheel', 'flower']
#   Formosa_lily,_Nagai_Park,_Osaka.jpg                ->  portrait  |  large  |  ['vase', 'bird', 'pinwheel', 'daisy', 'cabbage_butterfly', 'flower']
#   Frühlings_Enzian_Gentiana_verna_03.JPG             ->  landscape  |  large  |  ['pinwheel', 'pot', 'picket_fence', 'flower']
#   Karakaftja.jpg                                     ->  portrait  |  large  |  ['potted plant', 'walking_stick', 'pot', 'pineapple', 'flower']
#   LiliumBulbiferumCroceumBologna.jpg                 ->  landscape  |  large  |  ['orange', 'mushroom', 'earthstar', 'flower']
#   Lilium_michiganense_2.jpg                          ->  portrait  |  medium  |  ['coral_fungus', 'coral_reef', 'stinkhorn', 'flower']
#   Ohitashi_of_nanohana_2015.jpg                      ->  landscape  |  large  |  ['dining table', 'bowl', 'broccoli', 'cucumber', 'guacamole', 'flower']
#   Purple_puffer_(2257511230).jpg                     ->  portrait  |  medium  |  ['bee', 'cabbage_butterfly', 'fly', 'flower']
#   Red_Carnation_Flower.jpg                           ->  landscape  |  large  |  ['sulphur_butterfly', 'greenhouse', 'pot', 'flower']
#   Tanacetum_parthenium_-_Köhler–s_Medizinal-Pflanzen-036.jpg ->  portrait  |  medium  |  ['potted plant', 'limpkin', 'greenhouse', 'broom', 'flower']
#   Ukiyoe_calendar_June_2010_hokusai_--_yuri.jpg      ->  landscape  |  thumbnail  |  ['potted plant', 'comic_book', 'book_jacket', 'handkerchief', 'flower']
#   Ulex_europaeus3.jpg                                ->  landscape  |  medium  |  ['banana', 'rapeseed', 'bee', 'fly', 'flower']
#   Aouille_Tseque_and_Glacier_de_l'Aiguillette.jpg    ->  landscape  |  large  |  ['alp', 'volcano', 'valley', 'mountain']
#   Arollagletscher.jpg                                ->  portrait  |  medium  |  ['alp', 'promontory', 'cliff', 'mountain']
#   Becs_de_Bosson_depuis_le_Pas_de_Lona.jpg           ->  landscape  |  large  |  ['alp', 'cliff', 'geyser', 'mountain']
#   Besso_-_Blanc_de_Moming_-_Dent_Blanche.jpg         ->  landscape  |  large  |  ['alp', 'valley', 'mountain_tent', 'mountain']
#   Bigerhorn-balfrin-01.jpg                           ->  landscape  |  large  |  ['alp', 'valley', 'volcano', 'mountain']
#   Corbassiere4.JPG                                   ->  landscape  |  large  |  ['person', 'alp', 'promontory', 'ski', 'mountain']
#   Drehrestaurant_Mittelallalin.jpg                   ->  landscape  |  large  |  ['skis', 'alp', 'promontory', 'cliff', 'mountain']
#   Egginer_vom_Mittagshorn.JPG                        ->  landscape  |  large  |  ['alp', 'cliff', 'promontory', 'mountain']
#   FluchthornVSFromE.jpg                              ->  portrait  |  large  |  ['alp', 'valley', 'cliff', 'mountain']
#   Funivia_Rote_Nase_alt.JPG                          ->  landscape  |  large  |  ['bus', 'ski', 'alp', 'streetcar', 'mountain']
#   Hohtälli.JPG                                       ->  landscape  |  medium  |  ['valley', 'promontory', 'alp', 'mountain']
#   Jagerhorn0001.jpg                                  ->  landscape  |  medium  |  ['alp', 'valley', 'cliff', 'mountain']
#   Les_Diablons_depuis_Sorebois.jpg                   ->  landscape  |  large  |  ['alp', 'valley', 'mountain_tent', 'mountain']
#   MontRogneux.jpeg                                   ->  landscape  |  large  |  ['person', 'alp', 'snowmobile', 'ski', 'mountain']
#   Moosalp_Bonigersee.jpg                             ->  landscape  |  medium  |  ['valley', 'geyser', 'alp', 'mountain']
#   Otemma.jpg                                         ->  landscape  |  large  |  ['alp', 'ski', 'snowmobile', 'mountain']
#   Piolone0001.jpg                                    ->  landscape  |  medium  |  ['alp', 'valley', 'cliff', 'mountain']
#   Plattjen.jpg                                       ->  landscape  |  large  |  ['kite', 'alp', 'geyser', 'volcano', 'mountain']
#   Roc_d'Orzival.jpg                                  ->  landscape  |  large  |  ['alp', 'valley', 'cliff', 'mountain']
#   Saas-Grund_mit_Plattjen.jpg                        ->  landscape  |  large  |  ['valley', 'alp', 'cliff', 'mountain']
#   SchoenbielhornFromSE.jpg                           ->  landscape  |  large  |  ['alp', 'valley', 'cliff', 'mountain']
#   Seetalhorn.JPG                                     ->  landscape  |  large  |  ['cliff', 'alp', 'ibex', 'mountain']
#   SpechhornFromNW.JPG                                ->  portrait  |  large  |  ['volcano', 'alp', 'valley', 'mountain']
#   UlrichshornFromSW.jpg                              ->  landscape  |  large  |  ['alp', 'volcano', 'valley', 'mountain']
#   Wallis_Stellihorn_mg-k.jpg                         ->  landscape  |  medium  |  ['alp', 'valley', 'volcano', 'mountain']
#   Bearded_Mountaineer_(Oreonympha_nobilis).jpg       ->  portrait  |  large  |  ['apple', 'bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Black-tailed_Trainbearer_(Lesbia_victoriae).jpg    ->  portrait  |  medium  |  ['bird', 'hummingbird', 'jacamar', 'American_chameleon']
#   Blue-bearded_Helmetcrest.jpg                       ->  landscape  |  large  |  ['bird', 'bulbul', 'hummingbird', 'grasshopper']
#   ChaetocercusBurmeisteriKeulemans.jpg               ->  portrait  |  large  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Great_sapphirewing_(Pterophanes_cyanopterus_caeruleus)_male_Caldas.jpg ->  landscape  |  large  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Loddigesia_mirabilis_114707728.jpg                 ->  landscape  |  large  |  ['bird', 'jacamar', 'bee_eater', 'hummingbird']
#   Male_Blue-chinned_Sapphire_(Chlorestes_notatus).jpg ->  portrait  |  large  |  ['bird', 'hummingbird', 'jacamar', 'indigo_bunting']
#   Maleo_bird.PNG                                     ->  landscape  |  large  |  ['bird', 'goose', 'peacock', 'ruffed_grouse']
#   Mountain_velvetbreast_(Lafresnaya_lafresnayi_longirostris)_male_Caldas.jpg ->  square  |  large  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Numida_meleagris_-Kruger_National_Park,_South_Africa-8a.jpg ->  landscape  |  large  |  ['bird', 'peacock', 'partridge', 'bustard']
#   Oxypogon_guerinii_236915214.jpg                    ->  landscape  |  medium  |  ['bird', 'bulbul', 'hummingbird', 'coucal']
#   Oxypogon_guerinii_female.jpg                       ->  landscape  |  large  |  ['bird', 'hummingbird', 'bulbul', 'bustard']
#   Oxypogon_guerinii_lindenii.jpg                     ->  portrait  |  large  |  ['bird', 'bulbul', 'hummingbird', 'jacamar']
#   Oxypogon_stuebelii_-_Buffy_Helmetcrest_-_Colibrí_Chivito_del_Ruiz.jpg ->  portrait  |  medium  |  ['bird', 'bulbul', 'hummingbird', 'bee_eater']
#   Picaflor_de_arica.jpg                              ->  portrait  |  large  |  ['bird', 'hummingbird', 'jacamar', 'water_ouzel']
#   Scaly-breasted_Hummingbird_-_Sarapiqui_-_Costa_Rica_S4E0291_(26084747394).jpg ->  portrait  |  medium  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Schistes_albogularis_240980514_(cropped).jpg       ->  landscape  |  medium  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Schistes_geoffroyi_(Pico_de_cuña)_(22653616465).jpg ->  landscape  |  large  |  ['bird', 'hummingbird', 'jacamar', 'chickadee']
#   Stavenn_Maleo.jpg                                  ->  portrait  |  thumbnail  |  ['bird', 'hornbill', 'kite', 'black_stork']
#   Stephanoxis_loddigesii_244152090.jpg               ->  portrait  |  large  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Taoniscus.jpg                                      ->  portrait  |  thumbnail  |  ['bird', 'prairie_chicken', 'partridge', 'ptarmigan']
#   Thaumastura_cora_188341541.jpg                     ->  portrait  |  medium  |  ['bird', 'bee_eater', 'jacamar', 'hummingbird']
#   Violet-headed_Hummingbird_(Klais_guimeti)_2015-06-14_(1)_(40283795752).jpg ->  landscape  |  large  |  ['bird', 'indigo_bunting', 'jay', 'hummingbird']
#   White-bellied_Mountain-gem_(Oreopyra_hemileucus).jpg ->  portrait  |  thumbnail  |  ['bird', 'hummingbird', 'jacamar', 'bee_eater']
#   Área_de_Proteção_Ambiental_Serra_Dona_Francisca_-_Luiz_Alves_(108).jpg ->  landscape  |  large  |  ['bird', 'hummingbird', 'jacamar', 'bulbul']
#
# 118 images sauvegardées -> data/images_labels.json

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output
import io

image_list  = list(all_labels.keys())
current_idx = [0]

# ── Widgets ───────────────────────────────────────────────────────────
img_display   = widgets.Output()
tags_input    = widgets.Text(layout=widgets.Layout(width="400px"))
new_tag_input = widgets.Text(placeholder="New tag...", layout=widgets.Layout(width="200px"))
add_btn       = widgets.Button(description="Add", button_style="info")
save_btn      = widgets.Button(description="Save & Next ▶", button_style="success")
skip_btn      = widgets.Button(description="Skip", button_style="warning")
progress      = widgets.Label()
hint          = widgets.Label(value="Edit tags directly (comma-separated), or use the field below.")

def show_current():
    idx   = current_idx[0]
    fname = image_list[idx]
    progress.value   = f"Image {idx+1} / {len(image_list)} — {fname}"
    current_tags     = all_labels[fname].get("tags", [])
    tags_input.value = ", ".join(current_tags)

    # Find the actual file path
    for root, dirs, files in os.walk(IMAGE_DIR):
        if fname in files:
            path = os.path.join(root, fname)
            break

    with img_display:
        clear_output(wait=True)
        img = Image.open(path)
        img.thumbnail((400, 400))
        buf = io.BytesIO()
        img.save(buf, format="PNG")
        display(widgets.Image(value=buf.getvalue(), format="png"))

def on_add(b):
    tag = new_tag_input.value.strip().lower()
    if tag:
        current = [t.strip() for t in tags_input.value.split(",") if t.strip()]
        if tag not in current:
            current.append(tag)
        tags_input.value    = ", ".join(current)
        new_tag_input.value = ""

def on_save(b):
    fname = image_list[current_idx[0]]
    # Parse tags from the text field
    tags = [t.strip().lower() for t in tags_input.value.split(",") if t.strip()]
    all_labels[fname]["tags"] = tags
    # Save JSON immediately
    with open(OUTPUT_FILE, "w", encoding="utf-8") as f:
        json.dump(all_labels, f, indent=2, ensure_ascii=False)
    next_image()

def on_skip(b):
    next_image()

def next_image():
    if current_idx[0] < len(image_list) - 1:
        current_idx[0] += 1
        show_current()
    else:
        with img_display:
            clear_output()
            print("All images have been processed!")
        progress.value = "Done!"

add_btn.on_click(on_add)
save_btn.on_click(on_save)
skip_btn.on_click(on_skip)

# ── Layout ────────────────────────────────────────────────────────────
ui = widgets.VBox([
    progress,
    img_display,
    hint,
    widgets.Label("Current tags (editable directly):"),
    tags_input,
    widgets.HBox([new_tag_input, add_btn]),
    widgets.HBox([save_btn, skip_btn]),
])

show_current()
display(ui)
# Out:
# VBox(children=(Label(value='Image 1 / 118 — Aerial_view_of_Tashkent,_Uzbekistan.JPG'), Output(), Label(value='…
